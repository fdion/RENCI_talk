# %%
# %matplotlib inline
from stemgraphic import alpha
from stemgraphic.stopwords import *

# %% [markdown]
# ## "I'm picking up something on the radar!"

# %%
alpha.radar('air', ['are', 'hare', 'hair', 'eyre', 'heir', 'err', 'ere']);

# %% [markdown]
# ## "Kick it up a notch!"

# %% [markdown]
# Red Headed League vs. A Case of Identity (Sherlock Holmes stories)

# %%
fig = alpha.heatmap_grid('redh.txt', 'iden.txt') #, reverse=True)

# %% [markdown]
# 2 authors, 3 texts. Red Headed League and a Case of Identity (A.C. Doyle) are closer than The Gold Bug (E.A. Poe)

# %%
alpha.heatmap_grid('redh.txt', 'iden.txt', 'goldbug.txt');
